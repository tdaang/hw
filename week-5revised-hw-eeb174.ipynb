# %% [markdown]
# ## PART ONE
#
# ### 1. unique families: 194
#
# ```
# tail -n +4 formattednature.csv | cut -d "," -f +3 | sort | uniq | wc -l
# ```
# ### 2. which family is most represented? Trochilidae
#
# ```
# tail -n +4 formattednature.csv | cut -d "," -f 3 | sort | uniq -c
# ```
#
# ### 3. how many famiies have only one species represented? 60
# ```
# tail -n +4 formattednature.csv | cut -d "," -f 3 | sort | uniq -c| grep -w "1" -c
# ```
#
# ### 4. how many species are present in the ebird data? 239
# ```
# tail -n +2 formattedebirds.csv | cut -d "," -f 8 | sort | uniq | wc -l
# ```
# ### 5. how many species in each family of ebird?
# 4 Acanthisittidae (New Zealand Wrens) 76 Acanthizidae (Thornbills and Allies) 386 "Accipitridae (Hawks 80 Acrocephalidae (Reed-Warblers and Allies) 23 Aegithalidae (Long-tailed Tits) 5 Aegithinidae (Ioras) 14 Aegothelidae (Owlet-nightjars) 148 Alaudidae (Larks) 161 Alcedinidae (Kingfishers) 40 "Alcidae (Auks 364 "Anatidae (Ducks 3 Anhimidae (Screamers) 4 Anhingidae (Anhingas) 1 Anseranatidae (Magpie Goose) 152 Apodidae (Swifts) 7 Apterygidae (Kiwis) 3 Aramidae (Limpkin) 126 "Ardeidae (Herons 14 Artamidae (Woodswallows) 2 Atrichornithidae (Scrub-birds) 1 Balaenicipitidae (Shoebill) 11 Bernieridae (Malagasy Warblers) 4 Bombycillidae (Waxwings) 5 Brachypteraciidae (Ground-Rollers) 48 Bucconidae (Puffbirds) 74 Bucerotidae (Hornbills) 2 Bucorvidae (Ground-Hornbills) 3 Buphagidae (Oxpeckers) 11 Burhinidae (Thick-knees) 26 Cacatuidae (Cockatoos) 9 Calcariidae (Longspurs and Snow Buntings) 5 Callaeidae (Wattlebirds) 10 Calyptomenidae (African and Green Broadbills) 111 Campephagidae (Cuckooshrikes) 18 Capitonidae (New World Barbets) 124 Caprimulgidae (Nightjars and Allies) 93 Cardinalidae (Cardinals and Allies) 2 Cariamidae (Seriemas) 4 Casuariidae (Cassowaries and Emu) 12 Cathartidae (New World Vultures) 19 Certhiidae (Treecreepers) 42 Cettiidae (Bush-Warblers and Allies) 2 Chaetopidae (Rockjumpers) 90 Charadriidae (Plovers and Lapwings) 2 Chionidae (Sheathbills) 13 Chloropseidae (Leafbirds) 25 Ciconiidae (Storks) 10 Cinclidae (Dippers) 14 Cinclosomatidae (Quail-thrushes and Jewel-babblers) 222 Cisticolidae (Cisticolas and Allies) 9 Climacteridae (Australasian Treecreepers) 3 Cnemophilidae (Satinbirds) 7 Coliidae (Mousebirds) 425 Columbidae (Pigeons and Doves) 13 Conopophagidae (Gnateaters) 18 Coraciidae (Rollers) 2 Corcoracidae (White-winged Chough and Apostlebird) 190 "Corvidae (Crows 76 Cotingidae (Cotingas) 72 "Cracidae (Guans 26 Cracticidae (Bellmagpies and Allies) 206 Cuculidae (Cuckoos) 3 Dasyornithidae (Bristlebirds) 57 Dicaeidae (Flowerpeckers) 40 Dicruridae (Drongos) 33 Diomedeidae (Albatrosses) 1 Donacobiidae (Donacobius) 1 
#
# ```
# tail -n +2 formattedebirds.csv | cut -d "," -f 8 | sort | uniq -c
# ```

# %% [markdown]
# ## PART TWO

# %%
naturefile = open("/home/eeb177-student/Desktop/eeb-177/hw/formattednature.csv", encoding = "ISO-8859-1")
naturefile.readline()
naturedict = {}
for line in naturefile:
    split = line.split(",")
    naturedict[split[0]]=split[2]
for species in naturedict:
    print("Species " + species + " is in the family " + naturedict[species])
# Out:
# Species  is in the family
# Species Eupetomena_macroura is in the family Trochilidae
# Species Glyphorynchus_spirurus is in the family Dendrocolaptidae
# Species Plocepasser_mahali is in the family Passeridae
# Species Sephanoides_sephaniodes is in the family Trochilidae
# Species Arremon_schlegeli is in the family Emberizidae
# Species Ramphocaenus_melanurus is in the family Polioptilidae
# Species Phleocryptes_melanops is in the family Furnariidae
# Species Oxyruncus_cristatus is in the family Cotingidae
# Species Hemipus_picatus is in the family Campephagidae
# Species Pygarrhichas_albogularis is in the family Furnariidae
# Species Cypseloides_niger is in the family Apodidae
# Species Argusianus_argus is in the family Phasianidae
# Species Chelictinia_riocourii is in the family Accipitridae
# Species Niltava_grandis is in the family Muscicapidae
# Species Terathopius_ecaudatus is in the family Accipitridae
# Species Haplochelidon_andecola is in the family Hirundinidae
# ...

# %%
ebirdfile = open("/home/eeb177-student/Desktop/eeb-177/hw/formattedebirds.csv", encoding = "ISO-8859-1")
ebirddict = {}
ebirdfile.readline()
for row in ebirdfile:
    split = row.split(",")
    ebirddict[split[3]]=split[7]
for birdspecies in ebirddict:
    print("Species " + birdspecies + " is in the family " + ebirddict[birdspecies])
# Out:
# Species Trogon chionurus is in the family Trogonidae (Trogons)
# Species Sitta himalayensis is in the family Sittidae (Nuthatches)
# Species Fulica sp. is in the family "Rallidae (Rails
# Species Dryoscopus angolensis is in the family Malaconotidae (Bushshrikes and Allies)
# Species Sicalis taczanowskii is in the family Thraupidae (Tanagers and Allies)
# Species Falco jugger is in the family Falconidae (Falcons and Caracaras)
# Species Gallicolumba tristigmata is in the family Columbidae (Pigeons and Doves)
# Species Charadrius peronii is in the family Charadriidae (Plovers and Lapwings)
# Species Pardalotus punctatus is in the family Pardalotidae (Pardalotes)
# Species Fregetta grallaria is in the family Hydrobatidae (Storm-Petrels)
# Species Colaptes auratus/chrysoides is in the family Picidae (Woodpeckers)
# Species Toxorhamphus novaeguineae/poliopterus is in the family Melanocharitidae (Berrypeckers and Longbills)
# ...

# %%
from collections import Counter
countebirds = Counter(ebirddict.values())
for key, value in countebirds.items():
    print("The family " + str(key) + " has " + str(value) + " total species.")
# Out:
# The family  has 5 total species.
# The family Strigidae (Owls) has 318 total species.
# The family Mesitornithidae (Mesites) has 3 total species.
# The family Rhinocryptidae (Tapaculos) has 75 total species.
# The family Apodidae (Swifts) has 152 total species.
# The family Ramphastidae (Toucans) has 64 total species.
# The family Platysteiridae (Wattle-eyes and Batises) has 45 total species.
# The family Heliornithidae (Finfoots) has 3 total species.
# The family Icteridae (Troupials and Allies) has 166 total species.
# The family Burhinidae (Thick-knees) has 11 total species.
# The family Motacillidae (Wagtails and Pipits) has 130 total species.
# The family Lybiidae (African Barbets) has 64 total species.
# The family Oxyruncidae (Sharpbill) has 1 total species.
# The family Galbulidae (Jacamars) has 23 total species.
# The family Thinocoridae (Seedsnipes) has 4 total species.
# The family Psittaculidae (Old World Parrots) has 226 total species.
# ...

# %% [markdown]
# ## PART THREE
#
# Exercises from Python for Biologists

# %%
#percentage of amino acid residues, part one
protein = "MSRSLLLRFLLFLLLLPPLP"
aa = "R"
aa_count = protein.count(aa)
protein_length = len(protein)
percentage = aa_count * 100 / protein_length
print(percentage)

def get_aa_percentage(protein, aa):
    protein = protein.upper()
    aa = aa.upper()
    aa_count = protein.count(aa)
    protein_length = len(protein)
    percentage = aa_count * 100 / protein_length
    return percentage
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "r") == 10
# Out:
# 10.0

# %%
protein = "MSRSLLLRFLLFLLLLPPLP"
aa = "M"
aa_count = protein.count(aa)
protein_length = len(protein)
percentage = aa_count * 100 / protein_length
print(percentage)

def get_aa_percentage(protein, aa):
    protein = protein.upper()
    aa = aa.upper()
    aa_count = protein.count(aa)
    protein_length = len(protein)
    percentage = aa_count * 100 / protein_length
    return percentage
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "M") == 5
# Out:
# 5.0

# %%
protein = "MSRSLLLRFLLFLLLLPPLP"
aa = "Y"
aa_count = protein.count(aa)
protein_length = len(protein)
percentage = aa_count * 100 / protein_length
print(percentage)

def get_aa_percentage(protein, aa):
    protein = protein.upper()
    aa = aa.upper()
    aa_count = protein.count(aa)
    protein_length = len(protein)
    percentage = aa_count * 100 / protein_length
    return percentage
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "Y") == 0
# Out:
# 0.0

# %%
protein = "MSRSLLLRFLLFLLLLPPLP"
aa = "L"
aa_count = protein.count(aa)
protein_length = len(protein)
percentage = aa_count * 100 / protein_length
print(percentage)

def get_aa_percentage(protein, aa):
    protein = protein.upper()
    aa = aa.upper()
    aa_count = protein.count(aa)
    protein_length = len(protein)
    percentage = aa_count * 100 / protein_length
    return percentage
assert get_aa_percentage("msrslllrfllfllllpplp", "L") == 50
# Out:
# 50.0

# %%
#percentage of amino acid residues, part two
protein = "MSRSLLLRFLLFLLLLPPLP"
aa_list = ['M', 'L', 'F']

total = 0 
for aa in aa_list: 
    print("counting number of " + aa)
    aa = aa.upper() 
    aa_count = protein.count(aa) 

    total = total + aa_count 
    print("running total is " + str(total))
percentage = total * 100 / len(protein)
print("final percentage is " + str(percentage))
def get_aa_percentage(protein, aa_list=['A','I','L','M','F','W','Y','V']):
    protein = protein.upper() 
    protein_length = len(protein) 
    total = 0 
    for aa in aa_list: 
        aa = aa.upper() 
        aa_count = protein.count(aa) 
        total = total + aa_count 
    percentage = total * 100 / protein_length 
    return percentage
# Out:
# counting number of M
# running total is 1
# counting number of L
# running total is 11
# counting number of F
# running total is 13
# final percentage is 65.0
